# %%
import sys
sys.path.append('../')
from video_helper import VideoHelper

video_helper = VideoHelper()

# %%
DOWNSAMPLE_FACTOR=12

# %%
VIDEO = './videos/bee_on_a_flower_1080p.mp4'
OUTPUT_VIDEO = f'./videos/bee_on_a_flower_downsample_factor_{DOWNSAMPLE_FACTOR}.mp4'

# %%
# video_helper.plot_video_frames(VIDEO)

# %%
video_helper.downsample_video_and_save(VIDEO, OUTPUT_VIDEO, DOWNSAMPLE_FACTOR)
# Out:
# orginal frame dimensions: frame_width = 1920, frame_height = 1080, fps = 29
# downsampled frame dimensions: frame_width = 160, frame_height = 90, fps = 29
# ...
# Processing Frames:   5%|▍         | 14/286 [00:00<00:02, 134.32frames/s]
# downsampled_frame shape = (90, 160, 3)
# Processing Frames: 100%|██████████| 286/286 [00:01<00:00, 229.87frames/s]
# Video has been downsampled by a factor of 12 and saved as ./videos/bee_on_a_flower_downsample_factor_12.mp4

# %%
video_helper.check_if_video_is_valid(OUTPUT_VIDEO)
# Out:
# frame_width = 160, frame_height = 90, fps = 29

# %%
video_helper.plot_video_frames(OUTPUT_VIDEO)
