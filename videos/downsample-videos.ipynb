# %%
import sys
sys.path.append('../')
from video_helper import VideoHelper

video_helper = VideoHelper()

# %%
VIDEO = './videos/watch_on_arm_1080p.mp4'
OUTPUT_VIDEO = './videos/watch_on_arm_downsampled.mp4'

# %%
video_helper.plot_video_frames(VIDEO)

# %%
video_helper.downsample_video_and_save(VIDEO, OUTPUT_VIDEO, 4)
# Out:
# ...
# Processing Frames:  39%|███▉      | 31/80 [00:00<00:00, 153.94frames/s]
# downsampled_frame shape = (270, 480, 3)
# Processing Frames: 100%|██████████| 80/80 [00:00<00:00, 169.52frames/s]
# Video has been downsampled by a factor of 4 and saved as ./videos/watch_on_arm_downsampled.mp4
